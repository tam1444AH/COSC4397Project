# %%
import os

REPO_URL="https://github.com/UH-Insure/Evaluation.git"
REPO="Colab-Training"

os.chdir("/content")

# If repo exists, update it; otherwise, clone fresh
if os.path.exists(REPO):
    print(f"Repo '{REPO}' exists, pulling latest changes...")
    os.chdir(REPO)
    # !git reset --hard HEAD   # optional: discard local changes
    # !git pull
else:
    print(f"Cloning repo '{REPO}'...")
    # !git clone "$REPO_URL" "$REPO"
    os.chdir(REPO)
# Out:
# Cloning repo 'Colab-Training'...
# Cloning into 'Colab-Training'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 46 (delta 10), reused 38 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 22.24 KiB | 7.41 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import AutoPeftModelForCausalLM, PeftModel

# ----------------- USER CONFIG -----------------
BASE_MODEL_ID = "Qwen/Qwen3-Coder-30B-A3B-Instruct"     # Base model; change if you fine-tuned a different Qwen3 variant
ADAPTER_REPO  = "tam2003/SFT-Qwen3-30B-dsetV3"       # Your adapter repo on Hugging Face
TRUST_REMOTE_CODE = True                     # Qwen chat template typically needs this
USE_AUTOPEFT = True                          # True: load adapters directly from the adapter repo
MERGE_AND_UNLOAD = False                     # True to merge LoRA weights into the base for faster inference
DTYPE = torch.bfloat16 if torch.cuda.is_available() else torch.float32

GEN_KW = dict(
    max_new_tokens=1024,     # enough to hold the whole `cryptol` block
    do_sample=False,
    temperature=0.0,        # lower than 0.7 → more deterministic
    # top_p=0.9,
)

# -----------------------------------------------

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device, "| dtype:", DTYPE)
# Out:
# Device: cuda | dtype: torch.bfloat16

# %%
tokenizer = AutoTokenizer.from_pretrained(
    BASE_MODEL_ID if not USE_AUTOPEFT else ADAPTER_REPO,  # adapter repos often include correct tokenizer config
    use_fast=True,
    trust_remote_code=TRUST_REMOTE_CODE,
)
# Ensure pad token exists
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
print("Loaded tokenizer. EOS:", tokenizer.eos_token_id, "PAD:", tokenizer.pad_token_id)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Loaded tokenizer. EOS: 151645 PAD: 151643

# %%
# Fallback: load base model, then apply adapters
base = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL_ID,
    torch_dtype=DTYPE,
    device_map="auto",
    trust_remote_code=TRUST_REMOTE_CODE,
)
model = PeftModel.from_pretrained(base, ADAPTER_REPO)

# Optionally merge LoRA weights for faster inference (uses more RAM/VRAM)
if MERGE_AND_UNLOAD and hasattr(model, "merge_and_unload"):
    model = model.merge_and_unload()
    print("Merged LoRA weights into the base model.")

# Make sure pad token id is set for generation
if getattr(model.config, "pad_token_id", None) is None:
    model.config.pad_token_id = tokenizer.pad_token_id

_ = model.eval()
print("Model ready.")
# Out:
# config.json:   0%|          | 0.00/992 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# model-00006-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00007-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00005-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00008-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00003-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00002-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00001-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00004-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00009-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00010-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00011-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00012-of-00016.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00013-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00014-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00015-of-00016.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00016-of-00016.safetensors:   0%|          | 0.00/1.09G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/16 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: da8f6cb6-b528-43bf-857f-349fca855265)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen3-Coder-30B-A3B-Instruct/resolve/main/custom_generate/generate.py
# WARNING:huggingface_hub.utils._http:'(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: da8f6cb6-b528-43bf-857f-349fca855265)')' thrown while requesting HEAD https://huggingface.co/Qwen/Qwen3-Coder-30B-A3B-Instruct/resolve/main/custom_generate/generate.py
# Retrying in 1s [Retry 1/5].
# WARNING:huggingface_hub.utils._http:Retrying in 1s [Retry 1/5].
# adapter_config.json: 0.00B [00:00, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/3.38G [00:00<?, ?B/s]
# Model ready.

# %%
from src.eval_suite import Config, run_eval_suite
import pandas as pd

os.chdir("/content")

config = Config(
    MODEL_ID=ADAPTER_REPO,   # purely informational for local runs
    EVALS_PATH="/content/temp1.jsonl",
    TEMP_FILE="/content/Colab-Training/data/generated.txt",
    SYSTEM_PROMPT="Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).",
)

eval_df = pd.read_json(config.EVALS_PATH, lines=True)

def generate_cryptol(messages) -> str:
    inputs = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_tensors="pt",
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            inputs,
            **GEN_KW,
            pad_token_id=tokenizer.pad_token_id,
        )

    generated = outputs[0, inputs.shape[-1]:]  # only the new tokens
    text = tokenizer.decode(generated, skip_special_tokens=True)
    return text

# ---- 3. Run the eval suite using the local model ----
run_eval_suite(eval_df, config, execute=False, generate_fn=generate_cryptol)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Starting eval suite at 2025-11-30_03:01:19, 9 tasks to process.
#
# === Task 17 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol function that implements the tasks described below.
#
# ### Request:
# Task: Define the function `unflatten : {r,w} (fin r, 5 * w >= r, fin w) => [r] -> [w][5]` that pads its input with zeros and groups it into `w` blocks of 5 elements using `groupBy` in Cryptol. DO NOT include import statements, module declarations, or any other code.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# unflatten : {r,w} (fin r, 5 * w >= r, fin w) => [r] -> [w][5]
# unflatten xs = groupBy`{5} (xs # zero)
# ```
# [GENERATED END]
#
#
# === Task 18 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol function that implements the tasks described below.
#
# ### Request:
# Task: Write a Cryptol file that defines the functions `mk_curve_ops`, `ec_v1`, and `ec_v2`. The definition must follow the exact structure shown in the prompt: `mk_curve_ops` must construct a record containing fields `field`, `v1`, and `v2`, where `v1` calls `ec_v1` on the input parameter and `v2` calls `ec_v2` on the record being constructed. The functions must use the polymorphic types exactly as shown and must access `p.field.v0` correctly in `ec_v2`. The file must contain no module declaration and must consist only of the three definitions.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# mk_curve_ops : {p} (fin p) => { field : [p] } -> { field : [p], v1 : [p], v2 : [p] }
# mk_curve_ops p = { field = p.field, v1 = ec_v1 p.field, v2 = ec_v2 r }
#   where r = mk_curve_ops p
#
# ec_v1 : {p} (fin p) => [p] -> [p]
# ec_v1 x = x + 1
#
# ec_v2 : {p} (fin p) => { field : [p] } -> [p]
# ec_v2 r = r.field.v0 + 2
# ```
# [GENERATED END]
#
#
# === Task 19 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol function that implements the tasks described below.
#
# ### Request:
# Task: Write a Cryptol module named `T038` that declares an interface submodule `I` providing `x : [8]`, a submodule `F` that imports interface submodule `I` and defines `y = x + 1`, a submodule `P` that imports submodule `F` while exposing submodule `Q`, a submodule `Q` that defines `x = 11`, and finally an interface submodule `J` that imports submodule `F` through `P`. The structure must match the Cryptol module system rules exactly.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# module T038 where
#
# interface submodule I where
#   x : [8]
#
# submodule F where
#   import interface submodule I
#   y = x + 1
#
# submodule P where
#   submodule Q where
#     x = 11
#   submodule R where
#     import submodule Q
#     y = x + 1
#   import submodule R as submodule Q
#
# interface submodule J where
#   import submodule F through P
# ```
# [GENERATED END]
#
#
# === Task 20 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol function that implements the tasks described below.
#
# ### Request:
# Task: Reproduce exactly the four foreign function declarations `foreignAndCryptol`, `foreignAndNoCryptol`, `noForeignAndCryptol`, and `noForeignAndNoCryptol`, each using the C calling convention. Implement `foreignAndCryptol` to return its argument unchanged, leave `foreignAndNoCryptol` unimplemented, implement `noForeignAndCryptol` to return `x + 3`, and leave `noForeignAndNoCryptol` unimplemented. The file must contain only these four declarations.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# foreign foreignAndCryptol : [8] -> [8]
# foreignAndCryptol x = x
#
# foreign foreignAndNoCryptol : [8] -> [8]
#
# foreign noForeignAndCryptol : [8] -> [8]
# noForeignAndCryptol x = x + 3
#
# foreign noForeignAndNoCryptol : [8] -> [8]
# ```
# [GENERATED END]
#
#
# === Task 21 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol property that tests the function described below.
#
# ### Request:
# Task: Write a Cryptol module implementing parameterized AES encryption and decryption for key sizes 128, 192, and 256 bits. The module must import the AES algorithm, key expansion, and T-box modules exactly as specified, define `encrypt` and `decrypt` in terms of expanded keys, and include a property named `test` verifying that `decrypt k (encrypt k pt) == pt` for all valid keys and all 128-bit plaintexts.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# module Primitive::Symmetric::Cipher::Block::AES::Tests::Parameterized where
#
# import Primitive::Symmetric::Cipher::Block::AES::Algorithm as AES
# import Primitive::Symmetric::Cipher::Block::AES::KeyExpansion
# import Primitive::Symmetric::Cipher::Block::AES::TBox
#
# encrypt : {n} (fin n) => [32 * n][8] -> [128][8] -> [128][8]
# encrypt k pt = AES::encrypt (expandKey k) pt
#
# decrypt : {n} (fin n) => [32 * n][8] -> [128][8] -> [128][8]
# decrypt k ct = AES::decrypt (expandKey k) ct
#
# property test k pt = decrypt k (encrypt k pt) == pt
# ```
# [GENERATED END]
#
#
# === Task 22 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol property that tests the function described below.
#
# ### Request:
# Task: Write a complete Cryptol module implementing the Bivium stream cipher. The module must define `Bivium_stream`, `Bivium`, `Bivium_alt`, and all cycle-testing helpers. It must also define the four properties: `Bivium_correct`, `Bivium_search`, `Bivium_search_with_suffix`, and `Bivium_alt_equivalent`, using the exact IVs, suffix, and test keystream provided. The file must match the structure and behavior of the Bivium specification.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# ```cryptol
# module Primitive::Symmetric::Cipher::Stream::Bivium where
#
# import Common::utils
#
# Bivium_stream : [256] -> [1000][8]
# Bivium_stream iv = keystream
#   where
#     s = split iv
#     lfsr1 = take `{93} s
#     lfsr2 = drop `{93} s
#     keystream = [ ((lfsr1@0) ^ (lfsr2@0)) | _ <- [1..1000]
#                                             | lfsr1 <- lfsr1'
#                                             | lfsr2 <- lfsr2'
#                                             ]
#     lfsr1' = iterate update_lfsr1 lfsr1
#     lfsr2' = iterate update_lfsr2 lfsr2
#     update_lfsr1 lfsr = new_lfsr
#       where
#         feedback = (lfsr@65) ^ (lfsr@92)
#         new_lfsr = [feedback] # drop `{1} lfsr
#     update_lfsr2 lfsr = new_lfsr
#       where
#         feedback = (lfsr@68) ^ (lfsr@83)
#         new_lfsr = [feedback] # drop `{1} lfsr
#
# Bivium : [129] -> [1000][8]
# Bivium iv = keystream
#   where
#     lfsr1 = take `{93} iv
#     lfsr2 = drop `{93} iv
#     keystream = [ ((lfsr1@0) ^ (lfsr2@0)) | _ <- [1..1000]
#                                            | lfsr1 <- lfsr1'
#                                            | lfsr2 <- lfsr2'
#                                            ]
#     lfsr1' = iterate update_lfsr1 lfsr1
#     lfsr2' = iterate update_lfsr2 lfsr2
#     update_lfsr1 lfsr = new_lfsr
#       where
#         feedback = (lfsr@65) ^ (lfsr@92)
#         new_lfsr = [feedback] # drop `{1} lfsr
#     update_lfsr2 lfsr = new_lfsr
#       where
#         feedback = (lfsr@68) ^ (lfsr@83)
#         new_lfsr = [feedback] # drop `{1} lfsr
#
# Bivium_alt : [129] -> [1000][8]
# Bivium_alt iv = keystream
#   where
#     lfsr1 = take `{93} iv
#     lfsr2 = drop `{93} iv
#     keystream = [ ((lfsr1@0) ^ (lfsr2@0)) | _ <- [1..1000]
#                                            | lfsr1 <- lfsr1'
#                                            | lfsr2 <- lfsr2'
#                                            ]
#     lfsr1' = iterate update_lfsr1 lfsr1
#     lfsr2' = iterate update_lfsr2 lfsr2
#     update_lfsr1 lfsr = new_lfsr
#       where
#         feedback = (lfsr@65) ^ (lfsr@92)
#         new_lfsr = [feedback] # drop `{1} lfsr
#     update_lfsr2 lfsr = new_lfsr
#       where
#         feedback = (lfsr@68) ^ (lfsr@83)
#         new_lfsr = [feedback] # drop `{1} lfsr
#
# property Bivium_correct =
#   Bivium (zero # [True] # zero) == keystream
#   where
#     keystream = [
#       0x77, 0x00, 0x42, 0x00, 0x00, 0x00, 0x00, 0x00,
#       0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#       0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#       0x00, 0x00, 0x00, 0x00,
# ```
# [GENERATED END]
#
#
# === Task 23 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol function that implements the tasks described below.
#
# ### Request:
# Task: Write a Cryptol module instantiating the generic Simon block cipher specification for the Simon96_96 configuration. The module must be named `Primitive::Symmetric::Cipher::Block::Simon::Instantiations::Simon96_96` and must define `type n = 48`, `type m = 2`, `type T = 52`, and `type j = 2`. The module body must consist solely of re-exporting the base specification with these type overrides.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# module Primitive::Symmetric::Cipher::Block::Simon::Instantiations::Simon96_96 =
#     Primitive::Symmetric::Cipher::Block::Simon::Specification where
#         type n = 48
#         type m = 2
#         type T = 52
#         type j = 2
# ```
# [GENERATED END]
#
#
# === Task 24 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol property that tests the function described below.
#
# ### Request:
# Task: Write a Cryptol module implementing the FNV-1a 64-bit hash function, including padding, the FNV offset basis, prime constant, the block-processing logic, and a property `testsPass` that verifies the hash of the empty string, "a", and "foobar" equals the known answer test vectors provided.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# module Primitive::Keyless::Hash::FNV where
#
# padding : [8]
# padding = 0x01
#
# fnv_offset_basis_64 : [64]
# fnv_offset_basis_64 = 0xcbf29ce484222325
#
# fnv_prime_64 : [64]
# fnv_prime_64 = 0x100000001b3
#
# fnv1a_block : {n} (fin n) => [n][8] -> [64] -> [64]
# fnv1a_block bs hv =
#     if n == 0 then hv
#     else fnv1a_block bs' hv'
#         where hv' = (hv ^ b) * fnv_prime_64
#               b   = bs @ 0
#               bs' = drop `{1} bs
#
# fnv1a_64 : {n} (fin n) => [n][8] -> [64]
# fnv1a_64 bs = fnv1a_block bs (fnv_offset_basis_64 << padding)
#
# property testsPass =
#     fnv1a_64 [] == 0xcbf29ce484222325 &&
#     fnv1a_64 "a" == 0xaf63dc4c8601ec8c &&
#     fnv1a_64 "foobar" == 0x85944171f73967e8
# ```
# [GENERATED END]
#
#
# === Task 25 ===
#
# [PROMPT BEGIN]
# [SYSTEM]
# Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after).
#
# [USER]
# ### Instruction:
# Write a Cryptol property that tests the function described below.
#
# ### Request:
# Task: Write a Cryptol module containing SHA-224 test properties. Import the SHA224 hash implementation and define the properties `abcWorks`, `emptyStringWorks`, `alphabet448`, and `alphabet896`, each asserting that the hash of the corresponding fixed string equals the exact known-answer digest provided.
#
# [PROMPT END]
#
# [GENERATED BEGIN]
# ```cryptol
# module Primitive::Keyless::Hash::SHA2::Tests::SHA224 where
# import Primitive::Keyless::Hash::SHA2::Instantiations::SHA224 as SHA224
#
# property abcWorks = (SHA224::hashBytes "abc") == 0x23097d223405d8228642a477bda255b32aadbce4bda0b3f7e36c9da7
#
# property emptyStringWorks = (SHA224::hashBytes "") == 0xd14a028c2a3a2bc9476102bb288234c415a2b01f828ea62ac5b3e42f
#
# property alphabet448 = (SHA224::hashBytes "abcdbcdecdefdefgefghfghighijhijkijkljklmklmnlmnomnopnopq") == 0x75388b16512776cc5dba5da1fd890150b0c6455cb4f58b1952522525
#
# property alphabet896 = (SHA224::hashBytes "abcdefghbcdefghicdefghijdefghijkefghijklfghijklmghijklmnhijklmnoijklmnopjklmnopqklmnopqrlmnopqrsmnopqrstnopqrstu") == 0x09330c33f71147e83d192fc782cd1b4753111b173b3b05d22fa08086
# ```
# [GENERATED END]
#
#
# 2025-11-30_03-21-27
# Done processing all evals.

# %%
# Define conversation in the model's expected format
messages = [
   {"role": "system", "content": "Return exactly ONE fenced code block labeled `cryptol` and nothing else (no prose before/after)."},
    {"role": "user", "content": "Implement a Caesar cipher. Define the functions `encrypt` and `decrypt` with the signature: `{n} [8] -> [n][8] -> [n][8]`."},
]

# Build inputs using the chat template and ask the model to generate the assistant's reply
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,  # append assistant header so the model continues as assistant
    tokenize=True,
    return_tensors="pt"
).to(model.device)

with torch.no_grad():
    outputs = model.generate(
        inputs,
        **GEN_KW,
        pad_token_id=tokenizer.pad_token_id,
    )

generated = outputs[0, inputs.shape[-1]:]
text = tokenizer.decode(generated, skip_special_tokens=True)
print("Assistant:\n", text)
# Out:
# Assistant:
#  ```cryptol
# encrypt : {n} [8] -> [n][8] -> [n][8]
# encrypt shift plaintext = [((c + shift) % 256) | c <- plaintext]
#
# decrypt : {n} [8] -> [n][8] -> [n][8]
# decrypt shift ciphertext = [((c - shift) % 256) | c <- ciphertext]
# ```

# %%
def chat(system_prompt: str, user_prompt: str, **gen_kwargs):
    msgs = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]
    model_inputs = tokenizer.apply_chat_template(
        msgs, add_generation_prompt=True, tokenize=True, return_tensors="pt"
    ).to(model.device)
    with torch.no_grad():
        out = model.generate(model_inputs, **({**GEN_KW, **gen_kwargs}), pad_token_id=tokenizer.pad_token_id)
    completion = tokenizer.decode(out[0, model_inputs.shape[-1]:], skip_special_tokens=True)
    return completion

print(chat(
    "You are a precise software assistant.",
    "Explain what an Echo State Network is in two sentences."
))
# Out:
# An Echo State Network (ESN) is a type of recurrent neural network where only the output weights are trained, while the hidden layer weights are randomly assigned and fixed. The network leverages the "echo state property" to ensure that the hidden states depend only on a finite number of recent inputs, making it suitable for temporal sequence processing tasks.

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# ## Notes
# - If `AutoPeftModelForCausalLM.from_pretrained(ADAPTER_REPO)` fails because the adapter repo doesn't declare the base,
#   set `USE_AUTOPEFT=False` to load `BASE_MODEL_ID` first, then apply `PeftModel.from_pretrained(BASE_MODEL_ID, ADAPTER_REPO)`.
# - Keep `trust_remote_code=True` for Qwen so the tokenizer/model expose the correct **chat template**.
# - If you see CUDA OOM, consider running on CPU (`device_map=None`) or reducing `max_new_tokens` and using a smaller batch.
# - `MERGE_AND_UNLOAD=True` can speed up inference at the cost of more memory.
